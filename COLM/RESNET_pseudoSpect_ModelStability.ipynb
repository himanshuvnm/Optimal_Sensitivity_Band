# %% [markdown]
# # ResNet Sensitivity Band on CIFAR-10 / CIFAR-10-C

# %%
# !pip -q install torch torchvision numpy matplotlib tqdm requests

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

def publication_luxury_style():
    mpl.rcParams.update({
        # figure
        "figure.facecolor": "white",
        "axes.facecolor": "white",
        "savefig.facecolor": "white",
        "savefig.dpi": 400,
        "figure.dpi": 140,

        # font
        "font.family": "serif",
        "font.size": 16,
        "text.color": "black",
        "axes.labelcolor": "black",
        "axes.titlecolor": "black",

        # axes
        "axes.edgecolor": "black",
        "axes.linewidth": 1.2,
        "axes.titlesize": 20,
        "axes.labelsize": 18,

        # ticks
        "xtick.color": "black",
        "ytick.color": "black",
        "xtick.direction": "in",
        "ytick.direction": "in",
        "xtick.major.size": 5,
        "ytick.major.size": 5,
        "xtick.major.width": 1.0,
        "ytick.major.width": 1.0,
        "xtick.labelsize": 15,
        "ytick.labelsize": 15,

        # grid
        "axes.grid": True,
        "grid.color": "#D0D0D0",
        "grid.linestyle": "--",
        "grid.linewidth": 0.8,
        "grid.alpha": 0.7,

        # lines
        "lines.linewidth": 3.0,
        "lines.markersize": 9,

        # legend
        "legend.frameon": True,
        "legend.framealpha": 0.95,
        "legend.facecolor": "white",
        "legend.edgecolor": "#BBBBBB",
        "legend.fontsize": 14,

        # spines
        "axes.spines.top": False,
        "axes.spines.right": False,

        # layout
        "savefig.bbox": "tight",
        "figure.autolayout": False,
    })

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

def use_scientific_lux():

    mpl.rcParams.update({

        # Figure
        "figure.facecolor": "#0f172a",      # deep charcoal-blue
        "axes.facecolor": "#0f172a",
        "savefig.facecolor": "#0f172a",

        # Text
        "text.color": "#e2e8f0",
        "axes.labelcolor": "#e2e8f0",
        "axes.titlecolor": "#f8fafc",
        "xtick.color": "#cbd5e1",
        "ytick.color": "#cbd5e1",

        # Grid
        "axes.grid": True,
        "grid.color": "#334155",
        "grid.alpha": 0.35,
        "grid.linestyle": "-",
        "grid.linewidth": 0.8,

        # Lines
        "lines.linewidth": 2.5,
        "lines.markersize": 6,

        # Axes
        "axes.edgecolor": "#475569",
        "axes.linewidth": 1.2,

        # Font
        "font.size": 13,
        "axes.titlesize": 16,
        "axes.labelsize": 14,
        "legend.fontsize": 12,

        # Legend
        "legend.frameon": False,

        # Custom scientific color cycle
        "axes.prop_cycle": mpl.cycler(color=[
            "#1b998b",  # teal
            "#e84855",  # coral
            "#f9a826",  # amber
            "#9a8cfc",  # lavender
            "#3fa7d6",  # sky blue
            "#90be6d"   # muted green
        ])
    })

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

def set_luxury_scientific_style():

    colors = [
        "#0F4C81",  # deep sapphire blue
        "#E07A5F",  # burnt coral
        "#3D405B",  # midnight slate
        "#81B29A",  # jade green
        "#F2CC8F",  # warm sand
        "#C06C84",  # rose wine
        "#6A4C93",  # royal purple
        "#2A9D8F",  # teal
    ]

    mpl.rcParams.update({

        # Figure
        "figure.figsize": (7,5),
        "figure.dpi": 120,
        "savefig.dpi": 300,
        "figure.facecolor": "white",

        # Font
        "font.family": "serif",
        "font.size": 13,
        "axes.titlesize": 16,
        "axes.labelsize": 14,

        # Axes
        "axes.edgecolor": "#2E2E2E",
        "axes.linewidth": 1.2,
        "axes.prop_cycle": mpl.cycler(color=colors),

        # Grid
        "axes.grid": True,
        "grid.color": "#DADADA",
        "grid.linestyle": "--",
        "grid.linewidth": 0.7,

        # Ticks
        "xtick.direction": "in",
        "ytick.direction": "in",
        "xtick.major.size": 6,
        "ytick.major.size": 6,
        "xtick.major.width": 1,
        "ytick.major.width": 1,

        # Legend
        "legend.frameon": True,
        "legend.framealpha": 0.9,
        "legend.edgecolor": "#BBBBBB",
        "legend.fancybox": True,

        # Lines
        "lines.linewidth": 2.5,
        "lines.markersize": 7,

        # Layout
        "axes.spines.top": False,
        "axes.spines.right": False,

    })

set_luxury_scientific_style()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

def luxury_pub_style():

    colors = [
        "#1B3A6F",  # deep royal blue
        "#D1495B",  # crimson coral
        "#00798C",  # ocean teal
        "#EDAe49",  # amber gold
        "#6A4C93",  # royal purple
        "#2A9D8F",  # jade
        "#4C4C9D",  # indigo
    ]

    mpl.rcParams.update({

        # Figure
        "figure.figsize": (7,5),
        "figure.dpi": 120,
        "savefig.dpi": 300,
        "figure.facecolor": "white",

        # Fonts
        "font.family": "serif",
        "font.size": 13,
        "text.color": "black",

        # Axes
        "axes.labelcolor": "black",
        "axes.edgecolor": "black",
        "axes.linewidth": 1.2,
        "axes.titlesize": 16,
        "axes.labelsize": 14,
        "axes.prop_cycle": mpl.cycler(color=colors),

        # Ticks
        "xtick.color": "black",
        "ytick.color": "black",
        "xtick.direction": "in",
        "ytick.direction": "in",
        "xtick.major.size": 5,
        "ytick.major.size": 5,
        "xtick.major.width": 1,
        "ytick.major.width": 1,

        # Grid
        "axes.grid": True,
        "grid.color": "#D9D9D9",
        "grid.linestyle": "--",
        "grid.linewidth": 0.6,

        # Lines
        "lines.linewidth": 2.6,
        "lines.markersize": 7,

        # Legend
        "legend.frameon": False,
        "legend.fontsize": 12,

        # Spines
        "axes.spines.top": False,
        "axes.spines.right": False,

        # Save
        "savefig.bbox": "tight",
    })

luxury_pub_style()

# %%
import os, math, time, json, random
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T

import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# ---- Reproducibility ----
def seed_all(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

seed_all(0)

# ---- Device ----
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("device:", device)

# ---- High-quality plot defaults ----
plt.rcParams.update({
    "figure.dpi": 200,
    "savefig.dpi": 300,
    "font.size": 11,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "legend.fontsize": 10,
    "lines.linewidth": 2.0,
})
# Out:
# device: mps

# %% [markdown]
# # CIFAR-10 data loaders

# %%
DATA_ROOT = Path("./data").resolve()
DATA_ROOT.mkdir(parents=True, exist_ok=True)

# CIFAR-10 normalization (standard)
CIFAR_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR_STD  = (0.2470, 0.2435, 0.2616)

train_tf = T.Compose([
    T.RandomCrop(32, padding=4),
    T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize(CIFAR_MEAN, CIFAR_STD),
])

test_tf = T.Compose([
    T.ToTensor(),
    T.Normalize(CIFAR_MEAN, CIFAR_STD),
])

train_ds = torchvision.datasets.CIFAR10(root=str(DATA_ROOT), train=True, download=True, transform=train_tf)
test_ds  = torchvision.datasets.CIFAR10(root=str(DATA_ROOT), train=False, download=True, transform=test_tf)

batch_size = 128
num_workers = 0  # mac safe; increase if stable on your machine

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=False)
test_loader  = torch.utils.data.DataLoader(test_ds,  batch_size=256, shuffle=False, num_workers=num_workers, pin_memory=False)

print(len(train_ds), len(test_ds))
# Out:
# 50000 10000

# %% [markdown]
# # ResNet-18 (CIFAR-friendly)

# %%
def make_resnet18_cifar(num_classes=10):
    m = torchvision.models.resnet18(weights=None)
    m.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    m.maxpool = nn.Identity()
    m.fc = nn.Linear(m.fc.in_features, num_classes)
    return m

def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

model = make_resnet18_cifar().to(device)
print("ResNet-18 CIFAR params:", count_params(model))
# Out:
# ResNet-18 CIFAR params: 11173962

# %% [markdown]
# # Utilities: accuracy eval + CIFAR-10-C download + loader

# %%
# Clean accuracy

@torch.no_grad()
def eval_acc(model, loader):
    model.eval()
    correct, total = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        pred = logits.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()
    return correct / total

# %% [markdown]
# ## Download CIFAR-10-C (Hendrycks & Dietterich)

# %%
import requests
import tarfile

C10C_ROOT = Path("./cifar10c").resolve()
C10C_ROOT.mkdir(parents=True, exist_ok=True)

CIFAR10C_URL = "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar?download=1"

def download_cifar10c(root=C10C_ROOT):
    root = Path(root)
    tar_path = root / "CIFAR-10-C.tar"
    extracted_dir = root / "CIFAR-10-C"
    if extracted_dir.exists():
        print("CIFAR-10-C already extracted at:", extracted_dir)
        return extracted_dir

    if not tar_path.exists():
        print("Downloading CIFAR-10-C tar...")
        r = requests.get(CIFAR10C_URL, stream=True)
        r.raise_for_status()
        total = int(r.headers.get("content-length", 0))
        with open(tar_path, "wb") as f:
            pbar = tqdm(total=total, unit="B", unit_scale=True, desc="download")
            for chunk in r.iter_content(chunk_size=1<<20):
                if chunk:
                    f.write(chunk)
                    pbar.update(len(chunk))
            pbar.close()
        print("Downloaded:", tar_path)

    print("Extracting...")
    with tarfile.open(tar_path, "r") as tf:
        tf.extractall(path=root)
    print("Extracted to:", extracted_dir)
    return extracted_dir

c10c_dir = download_cifar10c(C10C_ROOT)
# Out:
# CIFAR-10-C already extracted at: /Users/singh_h/Downloads/27Feb2026_PseudoSpect_ModelStability/cifar10c/CIFAR-10-C
# /Users/singh_h/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## CIFAR-10-C loader (severity fixed or sweep)

# %%
C10C_CORRUPTIONS = [
    "gaussian_noise","shot_noise","impulse_noise",
    "defocus_blur","glass_blur","motion_blur","zoom_blur",
    "snow","frost","fog","brightness",
    "contrast","elastic_transform","pixelate","jpeg_compression",
]

def load_c10c_corruption(c10c_dir, corruption, severity):
    """
    Returns (images, labels) for a corruption at a given severity.
    severity in {1..5}. Each severity is a slice of 10k images.
    """
    c10c_dir = Path(c10c_dir)
    x = np.load(c10c_dir / f"{corruption}.npy")  # (50000,32,32,3), uint8
    y = np.load(c10c_dir / "labels.npy")         # (50000,)
    assert 1 <= severity <= 5
    start = (severity-1)*10000
    end   = severity*10000
    return x[start:end], y[start:end]

class CIFAR10CDataset(torch.utils.data.Dataset):
    def __init__(self, x_uint8, y, transform):
        self.x = x_uint8
        self.y = y
        self.transform = transform

    def __len__(self):
        return len(self.y)

    def __getitem__(self, i):
        img = self.x[i]  # uint8 HWC
        img = torchvision.transforms.functional.to_pil_image(img)
        img = self.transform(img)
        return img, int(self.y[i])

@torch.no_grad()
def eval_c10c(model, c10c_dir, severity=5, corruptions=None, batch_size=256):
    """
    Evaluate mean accuracy over corruptions at a severity.
    Returns mean, std across corruptions.
    """
    if corruptions is None:
        corruptions = C10C_CORRUPTIONS

    accs = []
    model.eval()
    for corr in corruptions:
        x, y = load_c10c_corruption(c10c_dir, corr, severity)
        ds = CIFAR10CDataset(x, y, transform=test_tf)
        loader = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=False, num_workers=0)
        a = eval_acc(model, loader)
        accs.append(a)
    return float(np.mean(accs)), float(np.std(accs)), {c:a for c,a in zip(corruptions, accs)}

# %% [markdown]
# # Sensitivity proxy $S(\theta)$ (finite-difference, safe + fast)
#
# We approximate $\|J(x)\|_{\text{op}}$ by sampling random unit input directions $v$ and computing:
#
# $$
# \|J(x)v\|_{2}\approx\left\|\dfrac{f(x+\epsilon v)-f(x)}{\epsilon}\right\|_2.
# $$

# %%
@torch.no_grad()
def _unit_noise_like(x):
    v = torch.randn_like(x)
    B = x.shape[0]
    denom = v.flatten(1).norm(dim=1, keepdim=True).view(B, *([1]*(x.ndim-1))) + 1e-12
    return v / denom

def sensitivity_sigma_mean_fd(model, x, eps=1e-3, n_vecs=2):
    """
    Returns scalar sigma_mean proxy on batch x.
    Uses forward passes only (no higher-order derivatives).
    """
    model.eval()
    x = x.detach()
    with torch.no_grad():
        fx = model(x)  # (B,K)
    vals = []
    for _ in range(n_vecs):
        v = _unit_noise_like(x)
        with torch.no_grad():
            fxp = model(x + eps*v)
        Jv = (fxp - fx) / eps  # (B,K)
        # L2 norm across classes
        vals.append(Jv.norm(dim=1))  # (B,)
    vals = torch.stack(vals, dim=0)  # (n_vecs,B)
    # proxy for operator norm: max over random directions, then mean over batch
    per_ex = vals.max(dim=0).values
    return float(per_ex.mean().item())

# %% [markdown]
# ### Train loop (stable vs unstable) with logging

# %%
def train_resnet(
    tag,
    lr,
    weight_decay,
    steps=2000,
    log_every=250,
    eps_fd=1e-3,
    n_vecs=2,
    sens_batch_cap=64,
):
    model = make_resnet18_cifar().to(device)
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    logs = {
        "step": [],
        "train_loss": [],
        "test_acc": [],
        "sigma_mean": [],
        "c10c_acc_mean": [],
        "c10c_acc_std": [],
    }

    it = iter(train_loader)
    pbar = tqdm(range(1, steps+1), desc=f"train {tag}")
    for step in pbar:
        try:
            x, y = next(it)
        except StopIteration:
            it = iter(train_loader)
            x, y = next(it)

        x, y = x.to(device), y.to(device)

        model.train()
        logits = model(x)
        loss = F.cross_entropy(logits, y)

        opt.zero_grad(set_to_none=True)
        loss.backward()
        opt.step()

        if step % log_every == 0:
            tloss = float(loss.item())
            ta = eval_acc(model, test_loader)

            # sensitivity on a small batch from test_loader
            xb, yb = next(iter(test_loader))
            xb = xb.to(device)[:sens_batch_cap]
            sigma = sensitivity_sigma_mean_fd(model, xb, eps=eps_fd, n_vecs=n_vecs)

            # CIFAR-10-C severity 5 (mean±std across corruptions)
            c10c_mu, c10c_sd, _ = eval_c10c(model, c10c_dir, severity=5)

            logs["step"].append(step)
            logs["train_loss"].append(tloss)
            logs["test_acc"].append(ta)
            logs["sigma_mean"].append(sigma)
            logs["c10c_acc_mean"].append(c10c_mu)
            logs["c10c_acc_std"].append(c10c_sd)

            pbar.set_postfix({
                "loss": f"{tloss:.3f}",
                "test": f"{ta:.3f}",
                "sigma": f"{sigma:.1f}",
                "c10c5": f"{c10c_mu:.3f}",
            })

    return model, logs

# %% [markdown]
# ### Run experiments: stable vs unstable

# %%
# Stable: smaller lr + weight decay
stable_model, stable_logs = train_resnet(
    tag="stable",
    lr=3e-4,
    weight_decay=1e-2,
    steps=2000,
    log_every=250,
    eps_fd=1e-3,
    n_vecs=2,
)

# Unstable: larger lr + no weight decay
unstable_model, unstable_logs = train_resnet(
    tag="unstable",
    lr=2e-3,
    weight_decay=0.0,
    steps=2000,
    log_every=250,
    eps_fd=1e-3,
    n_vecs=2,
)
# Out:
# ...
# train unstable:   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# ## Quadratic fit + optimal band utilities

# %%
def quadratic_fit(sigmas, accs):
    sigmas = np.asarray(sigmas, float)
    accs = np.asarray(accs, float)
    a, b, c = np.polyfit(sigmas, accs, deg=2)
    return float(a), float(b), float(c)

def sensitivity_optimal_band(a, b, c, eta=0.01):
    assert a < 0, "Need a < 0 for concave fit."
    s_star = -b / (2*a)
    R_star = a*s_star*s_star + b*s_star + c
    thr = (1-eta) * R_star

    # Solve a s^2 + b s + c = thr
    A, B, C = a, b, (c - thr)
    disc = B*B - 4*A*C
    disc = max(disc, 0.0)
    r1 = (-B - math.sqrt(disc)) / (2*A)
    r2 = (-B + math.sqrt(disc)) / (2*A)
    lo, hi = (min(r1, r2), max(r1, r2))
    return float(s_star), float(R_star), (float(lo), float(hi))

# %% [markdown]
# ## Make the “advanced” 2-panel figure (band + robustness)

# %%
#plt.style.use('default')
#set_luxury_scientific_style()
#luxury_pub_style()
publication_luxury_style()

# %%
def plot_band_and_robustness_advanced(
    stable_logs, unstable_logs,
    title="ResNet-18: Sensitivity band and severe-corruption robustness (CIFAR-10-C sev=5)",
    eta=0.01,
):
    steps = np.asarray(stable_logs["step"])
    sig_st = np.asarray(stable_logs["sigma_mean"])
    sig_un = np.asarray(unstable_logs["sigma_mean"])
    rob_st = np.asarray(stable_logs["c10c_acc_mean"])
    rob_un = np.asarray(unstable_logs["c10c_acc_mean"])
    rob_st_sd = np.asarray(stable_logs["c10c_acc_std"])
    rob_un_sd = np.asarray(unstable_logs["c10c_acc_std"])

    # Fit quadratic on pooled points (optional: only on unstable; here pooled)
    sig_all = np.concatenate([sig_st, sig_un])
    rob_all = np.concatenate([rob_st, rob_un])
    a,b,c = quadratic_fit(sig_all, rob_all)

    # If fit is not concave, still plot trajectories without band
    band = None
    s_star = None
    if a < 0:
        s_star, R_star, band = sensitivity_optimal_band(a,b,c,eta=eta)

    fig = plt.figure(figsize=(14.4, 12.2),dpi=300)
    gs = fig.add_gridspec(2, 1, height_ratios=[2.0, 1.4], hspace=0.22)

    ax1 = fig.add_subplot(gs[0,0])
    ax2 = fig.add_subplot(gs[1,0], sharex=ax1)

    # --- top: sensitivity trajectories ---
    if band is not None:
        lo, hi = band
        ax1.axhspan(lo, hi, alpha=0.18, label=f"{int(eta*100)}% optimal band [{lo:.1f},{hi:.1f}]")
        ax1.axhline(s_star, linestyle="--", linewidth=1.6, label=r"$\sigma^*$")

    ax1.plot(steps, sig_st, marker="o", label="stable")
    ax1.plot(steps, sig_un, marker="o", label="unstable")
    ax1.set_ylabel(r"Sensitivity $S(\theta)$ (sigma_mean)")
    ax1.set_title(title)
    ax1.grid(True, alpha=0.25)
    ax1.legend(loc="upper left", frameon=True)

    # annotate entry/exit for unstable
    if band is not None:
        inside = (sig_un >= lo) & (sig_un <= hi)
        if inside.any():
            idxs = np.where(inside)[0]
            enter_i, exit_i = idxs[0], idxs[-1]
            ax1.scatter([steps[enter_i]], [sig_un[enter_i]], s=80, zorder=5)
            ax1.annotate("enters band", xy=(steps[enter_i], sig_un[enter_i]),
                         xytext=(10, 16), textcoords="offset points",
                         arrowprops=dict(arrowstyle="->", lw=1.2))
            ax1.scatter([steps[exit_i]], [sig_un[exit_i]], s=80, zorder=5)
            ax1.annotate("last in band", xy=(steps[exit_i], sig_un[exit_i]),
                         xytext=(10, -22), textcoords="offset points",
                         arrowprops=dict(arrowstyle="->", lw=1.2))
            ax1.text(0.84, 0.92, "overshoot", transform=ax1.transAxes, va="top", alpha=0.9)

    # --- bottom: robustness trajectories ---
    ax2.plot(steps, rob_st, marker="o", label="stable sev=5")
    ax2.fill_between(steps, rob_st-rob_st_sd, rob_st+rob_st_sd, alpha=0.18)

    ax2.plot(steps, rob_un, marker="o", label="unstable sev=5")
    ax2.fill_between(steps, rob_un-rob_un_sd, rob_un+rob_un_sd, alpha=0.18)

    ax2.set_ylabel("CIFAR-10-C acc (sev=5)")
    ax2.set_xlabel("Training Step")
    ax2.grid(True, alpha=0.25)
    ax2.legend(loc="lower right", frameon=True)

    plt.savefig("figure2_resnet_sensitivity_band.pdf", bbox_inches="tight",dpi=300)
    plt.show()

    print("Quadratic fit (pooled): a,b,c =", a,b,c)
    if band is not None:
        print(f"sigma*={s_star:.3f}, band@{eta:.2%}=[{band[0]:.3f},{band[1]:.3f}]")
    else:
        print("Fit not concave; no band drawn.")

plot_band_and_robustness_advanced(stable_logs, unstable_logs, eta=0.01)
# Out:
# Quadratic fit (pooled): a,b,c = -8.185512372511893 2.793768098208071 0.23087130948319756
# sigma*=0.171, band@1.00%=[0.147,0.195]

# %% [markdown]
# ## Severity sweep on CIFAR-10-C (final “demo-quality” plot)

# %%
def severity_sweep(model, severities=(1,2,3,4,5)):
    out = {"severity": [], "mean": [], "std": []}
    for s in severities:
        mu, sd, _ = eval_c10c(model, c10c_dir, severity=s)
        out["severity"].append(s)
        out["mean"].append(mu)
        out["std"].append(sd)
    return out

stable_sev = severity_sweep(stable_model)
unstable_sev = severity_sweep(unstable_model)

# %%
plt.figure(figsize=(12.4, 6.2),dpi=300)
for out, lab in [(stable_sev, "stable"), (unstable_sev, "unstable")]:
    sev = np.array(out["severity"])
    mu  = np.array(out["mean"])
    sd  = np.array(out["std"])
    plt.plot(sev, mu, marker="o", label=lab)
    plt.fill_between(sev, mu-sd, mu+sd, alpha=0.18)
plt.xticks([1,2,3,4,5])
plt.xlabel("Severity (1–5)")
plt.ylabel("CIFAR-10-C Accuracy (mean over corruptions)",fontsize=14)
plt.title("ResNet-18: Corruption robustness vs Severity")
plt.grid(True, alpha=0.25)
plt.legend(frameon=True)
plt.savefig("fig3_severity_tradeoff.pdf", bbox_inches="tight",dpi=300)
plt.show()

# %% [markdown]
# ## Quadratic fit plot (robustness vs sensitivity scatter)

# %%
def plot_quadratic_fit(stable_logs, unstable_logs, title="ResNet-18: robustness vs sensitivity (sev=5)"):
    sig_st = np.asarray(stable_logs["sigma_mean"])
    sig_un = np.asarray(unstable_logs["sigma_mean"])
    rob_st = np.asarray(stable_logs["c10c_acc_mean"])
    rob_un = np.asarray(unstable_logs["c10c_acc_mean"])

    sig = np.concatenate([sig_st, sig_un])
    rob = np.concatenate([rob_st, rob_un])

    a,b,c = quadratic_fit(sig, rob)
    s_grid = np.linspace(sig.min()-1, sig.max()+1, 300)
    r_grid = a*s_grid**2 + b*s_grid + c

    xmin, xmax = sig.min(), sig.max()
    x_plot = np.linspace(xmin - 0.02, xmax + 0.02, 200)

    plt.figure(figsize=(10.2,6.4),dpi=300)
    plt.scatter(sig_st, rob_st, s=70, label="stable")
    plt.scatter(sig_un, rob_un, s=70, label="unstable")
    plt.xlim(-.1,.5)
    plt.ylim(0.1, 0.55)   # adjust based on your data
    plt.plot(s_grid, r_grid, label="quadratic fit")
    plt.xlabel(r"Sensitivity proxy $S(\theta)$")
    plt.ylabel("CIFAR-10-C acc (sev=5)")
    plt.title(title)
    plt.grid(True, alpha=0.25)
    plt.legend(frameon=True)
    plt.savefig("fig1_sensitivity_quadratic.pdf", bbox_inches="tight")
    plt.show()

    print("a,b,c =", a,b,c)
    if a < 0:
        s_star, R_star, band1 = sensitivity_optimal_band(a,b,c,eta=0.01)
        print(f"sigma*={s_star:.3f}, R*={R_star:.6f}, 1% band=[{band1[0]:.3f},{band1[1]:.3f}]")

plot_quadratic_fit(stable_logs, unstable_logs)
# Out:
# a,b,c = -8.185512372511893 2.793768098208071 0.23087130948319756
# sigma*=0.171, R*=0.469254, 1% band=[0.147,0.195]

# %%
def plot_sigma_vs_metric(stable_logs, unstable_logs, x_key="sigma_mean", y_key="noise_acc_mean", title="sigma vs metric"):
    """
    Scatter plot: sigma_mean (or sigma) vs chosen robustness metric.
    Examples:
      - y_key="noise_acc_mean"  (MNIST/CIFAR noise robustness)
      - y_key="c10c_acc_mean"   (CIFAR-10-C robustness)
    """
    def get_xy(logs):
        x = logs[x_key] if x_key in logs else logs.get("sigma", None)
        y = logs.get(y_key, None)
        if x is None or y is None:
            return None, None
        return np.array(x, dtype=float), np.array(y, dtype=float)

    xs, ys = get_xy(stable_logs)
    xu, yu = get_xy(unstable_logs)

    if xs is None or xu is None:
        raise KeyError(f"Missing required keys. Need x_key={x_key} and y_key={y_key} (or sigma).")

    plt.figure()
    plt.scatter(xs, ys, s=80, label="stable")
    plt.scatter(xu, yu, s=80, label="unstable")
    plt.xlabel(x_key)
    plt.ylabel(y_key)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
use_scientific_lux()
plot_quadratic_fit(stable_logs, unstable_logs)
# Out:
# a,b,c = -8.185512372511893 2.793768098208071 0.23087130948319756
# sigma*=0.171, R*=0.469254, 1% band=[0.147,0.195]

# %% [markdown]
# # COLM Tiny ViT model for CIFAR-10 [26 Mar 26]

# %%
import torch
import torch.nn as nn
import torchvision

def make_tiny_vit_cifar(num_classes=10):
    """
    Small Vision Transformer for 32x32 CIFAR-10.
    """
    model = torchvision.models.vision_transformer.VisionTransformer(
        image_size=32,
        patch_size=4,
        num_layers=6,
        num_heads=8,
        hidden_dim=256,
        mlp_dim=512,
        num_classes=num_classes,
        dropout=0.1,
        attention_dropout=0.1,
        representation_size=None,
        norm_layer=lambda dim: nn.LayerNorm(dim, eps=1e-6),
    )
    return model

vit = make_tiny_vit_cifar().to(device)
print("Tiny ViT params:", sum(p.numel() for p in vit.parameters() if p.requires_grad))
# Out:
# Tiny ViT params: 3195146

# %% [markdown]
# # Training loop for ViT

# %%
def train_vit(
    tag,
    lr,
    weight_decay,
    steps=2000,
    log_every=250,
    eps_fd=1e-3,
    n_vecs=2,
    sens_batch_cap=64,
):
    model = make_tiny_vit_cifar().to(device)
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    logs = {
        "step": [],
        "train_loss": [],
        "test_acc": [],
        "sigma_mean": [],
        "c10c_acc_mean": [],
        "c10c_acc_std": [],
    }

    it = iter(train_loader)
    pbar = tqdm(range(1, steps+1), desc=f"train {tag}")

    for step in pbar:
        try:
            x, y = next(it)
        except StopIteration:
            it = iter(train_loader)
            x, y = next(it)

        x, y = x.to(device), y.to(device)

        model.train()
        logits = model(x)
        loss = F.cross_entropy(logits, y)

        opt.zero_grad(set_to_none=True)
        loss.backward()
        opt.step()

        if step % log_every == 0:
            tloss = float(loss.item())
            ta = eval_acc(model, test_loader)

            xb, _ = next(iter(test_loader))
            xb = xb.to(device)[:sens_batch_cap]
            sigma = sensitivity_sigma_mean_fd(model, xb, eps=eps_fd, n_vecs=n_vecs)

            c10c_mu, c10c_sd, _ = eval_c10c(model, c10c_dir, severity=5)

            logs["step"].append(step)
            logs["train_loss"].append(tloss)
            logs["test_acc"].append(ta)
            logs["sigma_mean"].append(sigma)
            logs["c10c_acc_mean"].append(c10c_mu)
            logs["c10c_acc_std"].append(c10c_sd)

            pbar.set_postfix({
                "loss": f"{tloss:.3f}",
                "test": f"{ta:.3f}",
                "sigma": f"{sigma:.3f}",
                "c10c5": f"{c10c_mu:.3f}",
            })

    return model, logs

# %% [markdown]
# # Stable vs unstable ViT runs

# %%
vit_stable_model, vit_stable_logs = train_vit(
    tag="vit_stable",
    lr=3e-4,
    weight_decay=5e-2,
    steps=2000,
    log_every=250,
)

vit_unstable_model, vit_unstable_logs = train_vit(
    tag="vit_unstable",
    lr=1e-3,
    weight_decay=0.0,
    steps=2000,
    log_every=250,
)
# Out:
# ...
# train vit_unstable:   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# # 4) Quadratic fit for ViT

# %%
vit_sig_all = np.array(vit_stable_logs["sigma_mean"] + vit_unstable_logs["sigma_mean"])
vit_rob_all = np.array(vit_stable_logs["c10c_acc_mean"] + vit_unstable_logs["c10c_acc_mean"])

a, b, c = quadratic_fit(vit_sig_all, vit_rob_all)
print("ViT quadratic coefficients:", a, b, c)

if a < 0:
    s_star, R_star, band = sensitivity_optimal_band(a, b, c, eta=0.01)
    print(f"ViT sigma*={s_star:.6f}, R*={R_star:.6f}, band={band}")
else:
    print("Fit is not concave; no optimal band yet.")
# Out:
# ViT quadratic coefficients: -8.67560412977238 2.683503637299694 0.18257004953243244
# ViT sigma*=0.154658, R*=0.390083, band=(0.1334535043126409, 0.17586254989626643)

# %%
import numpy as np

def compute_overshoot_drop(logs, a, b, c, band_right):
    S = np.array(logs["sigma_mean"], dtype=float)
    R = np.array(logs["c10c_acc_mean"], dtype=float)

    # points after overshoot (right of band)
    mask = S > band_right

    if np.sum(mask) == 0:
        return {
            "drop_abs": None,
            "drop_pct": None,
            "R_worst": None
        }

    # worst robustness after overshoot
    R_worst = np.min(R[mask])

    # quadratic optimum
    S_star = -b / (2 * a)
    R_star = a * S_star**2 + b * S_star + c

    drop_abs = R_star - R_worst
    drop_pct = 100.0 * drop_abs / R_star

    return {
        "drop_abs": drop_abs,
        "drop_pct": drop_pct,
        "R_worst": R_worst
    }

# %% [markdown]
# # 5) Plot 1 — ViT quadratic law

# %%
plt.style.use('default')

# %%
def plot_vit_quadratic(stable_logs, unstable_logs, title="Tiny ViT: robustness vs sensitivity (sev=5)"):
    sig_st = np.asarray(stable_logs["sigma_mean"])
    sig_un = np.asarray(unstable_logs["sigma_mean"])
    rob_st = np.asarray(stable_logs["c10c_acc_mean"])
    rob_un = np.asarray(unstable_logs["c10c_acc_mean"])

    sig = np.concatenate([sig_st, sig_un])
    rob = np.concatenate([rob_st, rob_un])

    a, b, c = quadratic_fit(sig, rob)

    s_grid = np.linspace(sig.min(), sig.max(), 300)
    r_grid = a*s_grid**2 + b*s_grid + c

    plt.figure(figsize=(7.2, 4.4),dpi=300)
    plt.scatter(sig_st, rob_st, s=70, label="stable")
    plt.scatter(sig_un, rob_un, s=70, label="unstable")
    plt.plot(s_grid, r_grid, linewidth=2, label="quadratic fit")
    plt.xlabel("sigma_mean (sensitivity proxy)")
    plt.ylabel("CIFAR-10-C acc (sev=5)")
    plt.title(title)
    plt.grid(True, alpha=0.25)
    plt.legend(frameon=True)
    plt.show()

plot_vit_quadratic(vit_stable_logs, vit_unstable_logs)

# %% [markdown]
# # 6) Plot 2 — ViT trajectory + band

# %%
plot_band_and_robustness_advanced(
    vit_stable_logs,
    vit_unstable_logs,
    title="Tiny ViT: Sensitivity band and severe-corruption robustness",
    eta=0.01,
)
# Out:
# Quadratic fit (pooled): a,b,c = -8.67560412977238 2.683503637299694 0.18257004953243244
# sigma*=0.155, band@1.00%=[0.133,0.176]

# %% [markdown]
# # 7) Plot 3 — ViT severity sweep

# %%
def severity_sweep(model, severities=(1,2,3,4,5)):
    out = {"severity": [], "mean": [], "std": []}
    for s in severities:
        mu, sd, _ = eval_c10c(model, c10c_dir, severity=s)
        out["severity"].append(s)
        out["mean"].append(mu)
        out["std"].append(sd)
    return out

vit_stable_sev = severity_sweep(vit_stable_model)
vit_unstable_sev = severity_sweep(vit_unstable_model)

plt.figure(figsize=(7.2,4.2),dpi=300)
for out, label in [(vit_stable_sev, "stable"), (vit_unstable_sev, "unstable")]:
    sev = np.array(out["severity"])
    mu = np.array(out["mean"])
    sd = np.array(out["std"])
    plt.plot(sev, mu, marker="o", label=label)
    plt.fill_between(sev, mu-sd, mu+sd, alpha=0.18)

plt.xticks([1,2,3,4,5])
plt.xlabel("severity")
plt.ylabel("CIFAR-10-C acc")
plt.title("Tiny ViT: Corruption robustness vs severity")
plt.grid(True, alpha=0.25)
plt.legend(frameon=True)
plt.show()

# %%
import numpy as np

def fit_stats_from_logs(stable_logs, unstable_logs, a, b, c):
    # pooled points
    S = np.array(stable_logs["sigma_mean"] + unstable_logs["sigma_mean"], dtype=float)
    R = np.array(stable_logs["c10c_acc_mean"] + unstable_logs["c10c_acc_mean"], dtype=float)

    # fitted values
    R_hat = a * S**2 + b * S + c

    # R^2
    ss_res = np.sum((R - R_hat)**2)
    ss_tot = np.sum((R - np.mean(R))**2)
    r2 = 1.0 - ss_res / ss_tot

    # optimum
    S_star = -b / (2 * a)
    R_star = a * S_star**2 + b * S_star + c

    # overshoot = final unstable checkpoint
    S_over = float(unstable_logs["sigma_mean"][-1])
    R_over = float(unstable_logs["c10c_acc_mean"][-1])

    overshoot_drop_abs = R_star - R_over
    overshoot_drop_pct = 100.0 * overshoot_drop_abs / R_star

    return {
        "S_star": S_star,
        "R_star": R_star,
        "R2": r2,
        "S_over": S_over,
        "R_over": R_over,
        "overshoot_drop_abs": overshoot_drop_abs,
        "overshoot_drop_pct": overshoot_drop_pct,
    }

# %%
a = -8.185512372511893
b = 2.793768098208071
c = 0.23087130948319756

stats_resnet18 = fit_stats_from_logs(stable_logs, unstable_logs, a, b, c)
stats_resnet18
# Out:
# {'S_star': 0.17065322065787472,
#  'R_star': 0.469254071348414,
#  'R2': 0.4638465930007596,
#  'S_over': 0.23938412964344025,
#  'R_over': 0.46026666666666666,
#  'overshoot_drop_abs': 0.008987404681747357,
#  'overshoot_drop_pct': 1.9152534267676808}

# %%
a = -8.67560412977238
b = 2.683503637299694
c = 0.18257004953243244

stats_tinyvit = fit_stats_from_logs(vit_stable_logs, vit_unstable_logs, a, b, c)
stats_tinyvit
# Out:
# {'S_star': 0.15465802710445367,
#  'R_star': 0.3900827386686305,
#  'R2': 0.49596950366543724,
#  'S_over': 0.1841697096824646,
#  'R_over': 0.4163933333333334,
#  'overshoot_drop_abs': -0.02631059466470287,
#  'overshoot_drop_pct': -6.744875396051126}

# %%
band_right_vit = 0.17586254989626643
band_right_resnet = 0.195

# %%
a = -8.67560412977238
b = 2.683503637299694
c = 0.18257004953243244

overshoot_vit = compute_overshoot_drop(
    vit_unstable_logs,
    a, b, c,
    band_right_vit
)

print(overshoot_vit)
# Out:
# {'drop_abs': 0.01986940533529724, 'drop_pct': 5.0936386990904525, 'R_worst': 0.3702133333333333}

# %%
a = -8.185512372511893
b = 2.793768098208071
c = 0.23087130948319756

overshoot_resnet = compute_overshoot_drop(
          unstable_logs,
    a, b, c,
    band_right_resnet
)

print(overshoot_resnet)
# Out:
# {'drop_abs': 0.03958740468174726, 'drop_pct': 8.436241068296287, 'R_worst': 0.42966666666666675}

# %% [markdown]
# # Python / Matplotlib code for the hook figure [27 Mar 2026]

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Publication-quality hook figure
# -----------------------------
plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 12,
    "axes.titlesize": 13,
    "axes.labelsize": 13,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "legend.fontsize": 10,
    "axes.linewidth": 1.0,
})

# Color palette
deep_blue = "#1f4e79"
deep_red = "#8b1e3f"
soft_band = "#dbe9f6"
soft_gray = "#6b7280"
dark_text = "#111827"
gold = "#b58900"

# Create smooth non-monotonic curve
x = np.linspace(0, 10, 500)
y = -0.06 * (x - 5.2)**2 + 1.02
y = np.clip(y, 0.05, None)

# Optimal band and optimum
x_star = 5.2
band_left, band_right = 4.0, 6.4
y_star = -0.06 * (x_star - 5.2)**2 + 1.02

fig, ax = plt.subplots(figsize=(8.2, 4.8))

# Shaded optimal band
ax.axvspan(band_left, band_right, color=soft_band, alpha=0.85, zorder=0)

# Main curve
ax.plot(x, y, color=deep_blue, linewidth=3.0, solid_capstyle="round", zorder=3)

# Peak point
ax.scatter([x_star], [y_star], s=90, color=deep_red, zorder=5)
ax.axvline(x_star, color=deep_red, linestyle="--", linewidth=1.4, alpha=0.9, zorder=2)

# Regime markers
under_x = 1.7
under_y = -0.06 * (under_x - 5.2)**2 + 1.02
over_x = 8.4
over_y = -0.06 * (over_x - 5.2)**2 + 1.02

ax.scatter([under_x, over_x], [under_y, over_y], s=65, color=gold, zorder=5)

# Text annotations
ax.annotate(
    "under-sensitive",
    xy=(under_x, under_y),
    xytext=(0.9, 0.48),
    textcoords="data",
    arrowprops=dict(arrowstyle="->", lw=1.2, color=soft_gray),
    color=dark_text,
    ha="center"
)

ax.annotate(
    "optimal regime",
    xy=(x_star, y_star),
    xytext=(5.2, 1.12),
    textcoords="data",
    arrowprops=dict(arrowstyle="->", lw=1.2, color=soft_gray),
    color=dark_text,
    ha="center"
)

ax.annotate(
    "overshoot",
    xy=(over_x, over_y),
    xytext=(9.0, 0.48),
    textcoords="data",
    arrowprops=dict(arrowstyle="->", lw=1.2, color=soft_gray),
    color=dark_text,
    ha="center"
)

# Label the band
ax.text(
    (band_left + band_right) / 2,
    0.13,
    "optimal sensitivity band",
    color=deep_blue,
    ha="center",
    va="center",
    fontsize=11,
    fontweight="medium"
)

# Clean axis formatting
ax.set_xlim(0, 10)
ax.set_ylim(0, 1.18)
ax.set_xlabel("Sensitivity")
ax.set_ylabel("Robustness under distribution shift")

# Remove numeric ticks for conceptual look
ax.set_xticks([])
ax.set_yticks([])

# Minimal spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color(soft_gray)
ax.spines["bottom"].set_color(soft_gray)

# Optional title
ax.set_title("Conceptual illustration of the optimal sensitivity band", pad=10, color=dark_text)

plt.tight_layout()

# Save as publication-quality PDF
plt.savefig("fig1_hook_optimal_sensitivity_band.pdf", format="pdf", bbox_inches="tight",dpi=500)
plt.show()

# %% [markdown]
# # Editorial / luxurious hook figure code

# %%
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------------
# Editorial-style conceptual hook figure
# ------------------------------------
plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 600,
    "font.size": 12,
    "axes.titlesize": 14,
    "axes.labelsize": 13,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "axes.linewidth": 0.9,
    "font.family": "serif",
})

# Refined color palette
ink = "#111827"          # dark charcoal
blue = "#264653"         # deep blue-green
wine = "#7f1d1d"         # muted deep red
band = "#dbeafe"         # soft blue fill
gold = "#b7791f"         # warm accent
gray = "#6b7280"         # annotation gray
light_gray = "#d1d5db"   # subtle axis lines

# Data for conceptual curve
x = np.linspace(0, 10, 500)
y = -0.055 * (x - 5.3)**2 + 1.0
y = np.clip(y, 0.05, None)

x_star = 5.3
y_star = -0.055 * (x_star - 5.3)**2 + 1.0
band_left, band_right = 4.1, 6.5

fig, ax = plt.subplots(figsize=(8.6, 5.0))

# Soft background band
ax.axvspan(band_left, band_right, color=band, alpha=0.65, zorder=0)

# Main curve
ax.plot(x, y, color=blue, linewidth=3.2, solid_capstyle="round", zorder=3)

# Optimal point
ax.scatter([x_star], [y_star], s=95, color=wine, zorder=5)
ax.axvline(x_star, color=wine, linestyle=(0, (4, 4)), linewidth=1.3, alpha=0.9, zorder=2)

# Auxiliary points
left_x = 1.7
right_x = 8.4
left_y = -0.055 * (left_x - 5.3)**2 + 1.0
right_y = -0.055 * (right_x - 5.3)**2 + 1.0
ax.scatter([left_x, right_x], [left_y, right_y], s=55, color=gold, zorder=5)

# Regime labels
ax.text(1.25, 0.38, "under-sensitive", color=ink, ha="center", va="center", fontsize=11)
ax.text(5.3, 1.10, "optimal regime", color=ink, ha="center", va="center", fontsize=11)
ax.text(8.85, 0.38, "overshoot", color=ink, ha="center", va="center", fontsize=11)

# Thin guide annotations
ax.annotate(
    "", xy=(left_x, left_y), xytext=(1.25, 0.43),
    arrowprops=dict(arrowstyle="-", lw=1.0, color=gray)
)
ax.annotate(
    "", xy=(x_star, y_star), xytext=(5.3, 1.05),
    arrowprops=dict(arrowstyle="-", lw=1.0, color=gray)
)
ax.annotate(
    "", xy=(right_x, right_y), xytext=(8.85, 0.43),
    arrowprops=dict(arrowstyle="-", lw=1.0, color=gray)
)

# Band label
ax.text(
    (band_left + band_right) / 2, 0.12,
    "optimal sensitivity band",
    color=blue,
    fontsize=10.8,
    ha="center",
    va="center"
)

# Labels
ax.set_xlabel("Sensitivity", color=ink, labelpad=10)
ax.set_ylabel("Robustness under distribution shift", color=ink, labelpad=12)

# Minimal axis styling
ax.set_xlim(0, 10)
ax.set_ylim(0, 1.16)
ax.set_xticks([])
ax.set_yticks([])

for spine in ["top", "right"]:
    ax.spines[spine].set_visible(False)

ax.spines["left"].set_color(light_gray)
ax.spines["bottom"].set_color(light_gray)

# Optional subtle title
ax.set_title("A conceptual view of the optimal sensitivity band", color=ink, pad=12)

plt.tight_layout()

# Save
plt.savefig("fig1_hook_optimal_sensitivity_band_editorial.pdf",
            format="pdf", bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, Rectangle

plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 11,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.linewidth": 0.9,
    "font.family": "serif",
})

# palette
ink = "#111827"
blue = "#1d4ed8"
red = "#be123c"
band = "#dbeafe"
gray = "#6b7280"
light = "#e5e7eb"
gold = "#b45309"

fig = plt.figure(figsize=(13.5, 5))
gs = fig.add_gridspec(1, 3, width_ratios=[1.1, 1.35, 1.35], wspace=0.45)

# -------------------------
# Panel A: distribution shift
# -------------------------
ax1 = fig.add_subplot(gs[0, 0])
ax1.set_title("Distribution shift")

# simple stylized image blocks
for i, alpha in enumerate([1.0, 0.75, 0.45]):
    x0 = 0.08 + i * 0.3
    rect = Rectangle((x0, 0.28), 0.22, 0.42,
                     facecolor="#cbd5e1", edgecolor=gray, lw=1.0, alpha=alpha)
    ax1.add_patch(rect)
    # object blob
    ax1.add_patch(Rectangle((x0 + 0.06, 0.40), 0.10, 0.12,
                            facecolor="#94a3b8", edgecolor="none", alpha=alpha))
    ax1.text(x0 + 0.11, 0.20,
             ["clean", "mild", "severe"][i],
             ha="center", va="center", color=ink)

# arrows
ax1.annotate("", xy=(0.41, 0.49), xytext=(0.31, 0.49),
             arrowprops=dict(arrowstyle="->", lw=1.2, color=gray))
ax1.annotate("", xy=(0.71, 0.49), xytext=(0.61, 0.49),
             arrowprops=dict(arrowstyle="->", lw=1.2, color=gray))

ax1.text(0.5, 0.86, "increasing severity", ha="center", color=gray, fontsize=10)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
ax1.axis("off")

# -------------------------
# Panel B: sensitivity band
# -------------------------
ax2 = fig.add_subplot(gs[0, 1])
ax2.set_title("Optimal sensitivity band")

x = np.linspace(0, 10, 400)
y = -0.055 * (x - 5.2)**2 + 1.0
y = np.clip(y, 0.05, None)

x_star = 5.2
band_left, band_right = 4.0, 6.3
y_star = -0.055 * (x_star - 5.2)**2 + 1.0

ax2.axvspan(band_left, band_right, color=band, alpha=0.9, zorder=0)
ax2.plot(x, y, color=blue, lw=2.8)
ax2.scatter([x_star], [y_star], color=red, s=65, zorder=5)
ax2.axvline(x_star, color=red, ls="--", lw=1.2)

ax2.text(1.5, 0.35, "under-\nsensitive", ha="center", color=ink)
ax2.text(5.15, 1.05, "optimal", ha="center", color=ink)
ax2.text(8.5, 0.35, "over-\nsensitive", ha="center", color=ink)

ax2.text((band_left + band_right) / 2, 0.18, "band",
         ha="center", color=blue, fontsize=10)

ax2.set_xlabel("Sensitivity")
ax2.set_ylabel("Robustness")
ax2.set_xticks([])
ax2.set_yticks([])
for s in ["top", "right"]:
    ax2.spines[s].set_visible(False)
ax2.spines["left"].set_color(light)
ax2.spines["bottom"].set_color(light)

# -------------------------
# Panel C: training dynamics
# -------------------------
ax3 = fig.add_subplot(gs[0, 2])
ax3.set_title("Training dynamics")

steps = np.arange(1, 9)
stable = np.array([0.18, 0.27, 0.39, 0.47, 0.54, 0.58, 0.60, 0.62])
unstable = np.array([0.12, 0.32, 0.49, 0.58, 0.73, 0.88, 0.80, 0.91])

ax3.axhspan(0.52, 0.67, color=band, alpha=0.9, zorder=0)
ax3.plot(steps, stable, marker="o", color=blue, lw=2.2, label="stable")
ax3.plot(steps, unstable, marker="o", color=red, lw=2.2, label="unstable")

ax3.text(7.2, 0.61, "near band", color=blue, fontsize=10)
ax3.text(6.4, 0.90, "overshoot", color=red, fontsize=10)

# robustness consequence arrows
arr1 = FancyArrowPatch((7.8, 0.62), (8.5, 0.72), arrowstyle="->",
                       mutation_scale=12, lw=1.2, color=blue)
arr2 = FancyArrowPatch((7.8, 0.90), (8.5, 0.36), arrowstyle="->",
                       mutation_scale=12, lw=1.2, color=red)
ax3.add_patch(arr1)
ax3.add_patch(arr2)
ax3.text(8.4, 0.75, "robust", color=blue, va="center")
ax3.text(8.4, 0.30, "brittle", color=red, va="center")

ax3.set_xlim(1, 9.2)
ax3.set_ylim(0.05, 1.0)
ax3.set_xlabel("Training time")
ax3.set_ylabel("Sensitivity")
ax3.set_xticks([])
ax3.set_yticks([])
for s in ["top", "right"]:
    ax3.spines[s].set_visible(False)
ax3.spines["left"].set_color(light)
ax3.spines["bottom"].set_color(light)
ax3.legend(frameon=False, loc="upper left")

fig.suptitle("A sensitivity-band view of robustness under distribution shift",
             fontsize=15, color=ink, y=1.08)

#plt.tight_layout()
plt.savefig("fig0_sensitivity_band_story.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 11,
    "axes.titlesize": 11,
    "axes.labelsize": 11,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.linewidth": 0.8,
    "font.family": "serif",
})

# palette
ink = "#111827"
blue = "#1d4ed8"
red = "#be123c"
band = "#dbeafe"
gray = "#6b7280"
light = "#d1d5db"
panel_bg = "#f8fafc"

fig = plt.figure(figsize=(13.8, 4.0))
gs = fig.add_gridspec(1, 3, width_ratios=[1.05, 1.25, 1.35], wspace=0.42)

# -------------------------
# Panel A: Distribution shift
# -------------------------
ax1 = fig.add_subplot(gs[0, 0])
ax1.set_facecolor(panel_bg)
ax1.set_title("Distribution shift", color=ink, pad=10, fontsize=11)

# larger boxes for better visual balance
box_x = [0.06, 0.37, 0.68]
alphas = [1.0, 0.82, 0.65]
labels = ["clean", "mild", "severe"]

for x0, a, lab in zip(box_x, alphas, labels):
    ax1.add_patch(Rectangle((x0, 0.27), 0.23, 0.42,
                            facecolor="#cbd5e1", edgecolor=gray, lw=1.0, alpha=a))
    ax1.add_patch(Rectangle((x0 + 0.055, 0.39), 0.10, 0.12,
                            facecolor="#94a3b8", edgecolor="none", alpha=a))
    ax1.text(x0 + 0.115, 0.20, lab, ha="center", color=ink, fontsize=10)

# arrows
ax1.annotate("", xy=(0.37, 0.48), xytext=(0.31, 0.48),
             arrowprops=dict(arrowstyle="->", lw=1.2, color=gray))
ax1.annotate("", xy=(0.68, 0.48), xytext=(0.62, 0.48),
             arrowprops=dict(arrowstyle="->", lw=1.2, color=gray))

ax1.text(0.5, 0.82, "increasing severity", ha="center", color=gray, fontsize=10)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
ax1.axis("off")

# -------------------------
# Panel B: Sensitivity band
# -------------------------
ax2 = fig.add_subplot(gs[0, 1])
ax2.set_facecolor(panel_bg)
ax2.set_title("Optimal sensitivity band", color=ink, pad=10, fontsize=11)

x = np.linspace(0, 10, 400)
y = -0.055 * (x - 5.2)**2 + 1.0
y = np.clip(y, 0.05, None)

x_star = 5.2
y_star = -0.055 * (x_star - 5.2)**2 + 1.0
band_left, band_right = 4.0, 6.2

ax2.axvspan(band_left, band_right, color=band, alpha=0.85, zorder=0)
ax2.plot(x, y, color=blue, lw=2.6, zorder=2)
ax2.scatter([x_star], [y_star], color=red, s=70, zorder=3)
ax2.axvline(x_star, color=red, ls=(0, (4, 3)), lw=1.1, alpha=0.85, zorder=1)

# cleaner labels
ax2.text(x_star, 1.02, "optimal", ha="center", va="bottom", color=ink, fontsize=10)
ax2.text((band_left + band_right)/2, 0.17, "optimal band", ha="center", color=blue, fontsize=10)

ax2.text(1.3, 0.42, "under-\nsensitive", ha="center", color=gray, fontsize=10)
ax2.text(8.7, 0.42, "over-\nsensitive", ha="center", color=gray, fontsize=10)

ax2.set_xlabel("Sensitivity", color=ink, labelpad=2)
ax2.set_ylabel("Robustness", color=ink, labelpad=4)
ax2.set_xticks([])
ax2.set_yticks([])

for s in ["top", "right"]:
    ax2.spines[s].set_visible(False)
ax2.spines["left"].set_color(light)
ax2.spines["bottom"].set_color(light)

# -------------------------
# Panel C: Training dynamics
# -------------------------
ax3 = fig.add_subplot(gs[0, 2])
ax3.set_facecolor(panel_bg)
ax3.set_title("Training dynamics", color=ink, pad=10, fontsize=11)

steps = np.arange(1, 9)
stable = np.array([0.18, 0.27, 0.39, 0.47, 0.54, 0.58, 0.60, 0.62])
unstable = np.array([0.12, 0.32, 0.49, 0.58, 0.73, 0.88, 0.80, 0.91])

ax3.axhspan(0.50, 0.68, color=band, alpha=0.85, zorder=0)
ax3.plot(steps, stable, marker="o", ms=7, color=blue, lw=2.2, label="stable")
ax3.plot(steps, unstable, marker="o", ms=7, color=red, lw=2.2, label="unstable")

# reduced annotation clutter
ax3.text(6.9, 0.61, "near band", color=blue, fontsize=10)
ax3.text(6.1, 0.90, "overshoot", color=red, fontsize=10)

# outcome arrows placed with more room
ax3.annotate("robust", xy=(8, 0.62), xytext=(8.8, 0.73),
             color=blue, fontsize=10,
             arrowprops=dict(arrowstyle="<-", lw=1.2, color=blue))
ax3.annotate("brittle", xy=(7.9, 0.90), xytext=(8.8, 0.30),
             color=red, fontsize=10,
             arrowprops=dict(arrowstyle="<-", lw=1.2, color=red))

ax3.set_xlabel("Training time", color=ink, labelpad=2)
ax3.set_ylabel("Sensitivity", color=ink, labelpad=4)
ax3.set_xticks([])
ax3.set_yticks([])

for s in ["top", "right"]:
    ax3.spines[s].set_visible(False)
ax3.spines["left"].set_color(light)
ax3.spines["bottom"].set_color(light)

ax3.legend(frameon=False, loc="upper left", fontsize=10)

ax1.text(-0.15, 1.05, "(a)", transform=ax1.transAxes, fontsize=12)
ax2.text(-0.15, 1.05, "(b)", transform=ax2.transAxes, fontsize=12)
ax3.text(-0.15, 1.05, "(c)", transform=ax3.transAxes, fontsize=12)

fig.suptitle("A sensitivity-band view of robustness under distribution shift",
             fontsize=15, color=ink, y=1.06)

#plt.tight_layout(pad=2.2)
plt.savefig("fig0_sensitivity_band_story_polished.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, FancyArrowPatch, Circle
import numpy as np

plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 11,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "font.family": "serif",
})

# Color palette
ink = "#111827"
blue = "#1d4ed8"
red = "#be123c"
gray = "#6b7280"
light = "#d1d5db"
soft_blue = "#dbeafe"
soft_red = "#fde2e2"
soft_gray = "#f8fafc"
gold = "#b45309"

fig, ax = plt.subplots(figsize=(12.2, 4.8))
ax.set_xlim(0, 14)
ax.set_ylim(0, 6)
ax.axis("off")

# -----------------------
# Panel backgrounds
# -----------------------
ax.add_patch(Rectangle((0.3, 1.0), 6.2, 4.5, facecolor=soft_gray, edgecolor=light, lw=1.0))
ax.add_patch(Rectangle((7.5, 1.0), 6.2, 4.5, facecolor=soft_gray, edgecolor=light, lw=1.0))

# Titles
ax.text(3.4, 5.25, "Vision Transformer (Tiny ViT)", ha="center", va="center",
        fontsize=12, color=ink, fontweight="semibold")
ax.text(10.6, 5.25, "Residual CNN (ResNet-18)", ha="center", va="center",
        fontsize=12, color=ink, fontweight="semibold")

# -----------------------
# Left panel: ViT
# -----------------------

# Input image
ax.add_patch(Rectangle((0.8, 2.6), 1.0, 1.0, facecolor="#cbd5e1", edgecolor=gray, lw=1.0))
ax.text(1.3, 2.25, "input", ha="center", color=ink, fontsize=10)

# Patch blocks
patch_x0 = 2.4
patch_y0 = 2.45
patch_w = 0.22
gap = 0.05
for i in range(4):
    for j in range(4):
        ax.add_patch(Rectangle(
            (patch_x0 + j*(patch_w+gap), patch_y0 + i*(patch_w+gap)),
            patch_w, patch_w,
            facecolor=soft_blue, edgecolor=blue, lw=0.5
        ))
ax.text(2.95, 2.05, "patches", ha="center", color=ink, fontsize=10)

# Arrow input -> patches
ax.add_patch(FancyArrowPatch((1.85, 3.1), (2.25, 3.1),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Embedding tokens
embed_x = 4.15
for i in range(5):
    ax.add_patch(Rectangle((embed_x, 2.35 + i*0.34), 0.5, 0.22,
                           facecolor="#bfdbfe", edgecolor=blue, lw=0.8))
ax.text(4.4, 2.05, "token\nembeddings", ha="center", color=ink, fontsize=10)

# Arrow patches -> embeddings
ax.add_patch(FancyArrowPatch((3.55, 3.1), (4.0, 3.1),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Attention blocks
attn_x = 5.25
for i in range(3):
    ax.add_patch(Rectangle((attn_x, 2.0 + i*0.85), 0.9, 0.55,
                           facecolor=soft_blue, edgecolor=blue, lw=1.0))
    ax.text(attn_x + 0.45, 2.28 + i*0.85, "MHSA", ha="center", va="center",
            color=ink, fontsize=9)
ax.text(5.7, 1.65, "attention\nblocks", ha="center", color=ink, fontsize=10)

# Arrow embeddings -> attn
ax.add_patch(FancyArrowPatch((4.7, 3.1), (5.1, 3.1),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Global sensitivity annotation
ax.text(3.9, 4.55, "global sensitivity\npropagation", ha="center",
        color=blue, fontsize=10)

# Curved global mixing arrows
for y1, y2 in [(2.4, 4.0), (4.0, 2.4)]:
    ax.add_patch(FancyArrowPatch((5.2, y1), (6.1, y2),
                                 connectionstyle="arc3,rad=0.3",
                                 arrowstyle="->", mutation_scale=9,
                                 lw=1.0, color=blue, alpha=0.7))

# Final representation
ax.add_patch(Circle((6.15, 3.1), 0.18, facecolor=blue, edgecolor="none", alpha=0.9))
ax.text(6.15, 2.05, "global\nrepresentation", ha="center", color=ink, fontsize=10)

# -----------------------
# Right panel: ResNet
# -----------------------

# Input image
ax.add_patch(Rectangle((8.0, 2.6), 1.0, 1.0, facecolor="#cbd5e1", edgecolor=gray, lw=1.0))
ax.text(8.5, 2.25, "input", ha="center", color=ink, fontsize=10)

# Arrow input -> conv
ax.add_patch(FancyArrowPatch((9.05, 3.1), (9.45, 3.1),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Convolution stem
ax.add_patch(Rectangle((9.55, 2.65), 0.8, 0.9, facecolor=soft_red, edgecolor=red, lw=1.0))
ax.text(9.95, 3.1, "conv", ha="center", va="center", color=ink, fontsize=10)
ax.text(9.95, 2.15, "local\nfeatures", ha="center", color=ink, fontsize=10)

# Arrow stem -> residual blocks
ax.add_patch(FancyArrowPatch((10.4, 3.1), (10.75, 3.1),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Residual hierarchy
block_x = [10.9, 11.75, 12.6]
block_h = [0.6, 0.8, 1.0]
for x0, h in zip(block_x, block_h):
    ax.add_patch(Rectangle((x0, 3.1 - h/2), 0.55, h,
                           facecolor=soft_red, edgecolor=red, lw=1.0))
    ax.text(x0 + 0.275, 3.1, "res", ha="center", va="center", color=ink, fontsize=9)

# Local + hierarchical annotation
ax.text(11.8, 4.5, "local + hierarchical\nsensitivity propagation",
        ha="center", color=red, fontsize=10)

# small skip arrows
for x0 in block_x:
    ax.add_patch(FancyArrowPatch((x0, 3.8), (x0 + 0.55, 3.8),
                                 connectionstyle="arc3,rad=0.4",
                                 arrowstyle="->", mutation_scale=8,
                                 lw=0.9, color=red, alpha=0.7))

# Arrow to pooled rep
ax.add_patch(FancyArrowPatch((13.2, 3.1), (13.45, 3.1),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Final representation
ax.add_patch(Circle((13.55, 3.1), 0.18, facecolor=red, edgecolor="none", alpha=0.9))
ax.text(13.55, 2.05, "pooled\nrepresentation", ha="center", color=ink, fontsize=10)

# -----------------------
# Shared message strip
# -----------------------
ax.plot([0.8, 13.2], [0.7, 0.7], color=light, lw=1.2)
ax.text(7.0, 0.42,
        "Different sensitivity pathways, same non-monotonic robustness law",
        ha="center", va="center", fontsize=11, color=ink, fontweight="medium")

# Panel labels
ax.text(0.45, 5.45, "(a)", fontsize=11, color=gray)
ax.text(7.65, 5.45, "(b)", fontsize=11, color=gray)

plt.tight_layout(pad=1.5)
plt.savefig("fig_architecture_sensitivity_pathways.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, FancyArrowPatch, Circle

plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 11,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "font.family": "serif",
})

# colors
ink = "#111827"
blue = "#1d4ed8"
red = "#be123c"
gray = "#6b7280"
light = "#cbd5e1"
soft_blue = "#dbeafe"
soft_red = "#fde2e2"

fig, ax = plt.subplots(figsize=(12.4, 4.2))
ax.set_xlim(0, 14)
ax.set_ylim(0, 5.2)
ax.axis("off")

# -------------------------
# Titles
# -------------------------
ax.text(3.35, 4.85, "(a)", color=gray, fontsize=11, ha="right", va="center")
ax.text(3.55, 4.85, "Vision Transformer (Tiny ViT)",
        color=ink, fontsize=13, fontweight="semibold", ha="center", va="center")

ax.text(10.15, 4.85, "(b)", color=gray, fontsize=11, ha="right", va="center")
ax.text(10.45, 4.85, "Residual CNN (ResNet-18)",
        color=ink, fontsize=13, fontweight="semibold", ha="center", va="center")

# -------------------------
# Left panel: ViT
# -------------------------
# Input
ax.add_patch(Rectangle((0.75, 2.0), 1.0, 1.0, facecolor="#cbd5e1", edgecolor=gray, lw=1.0))
ax.text(1.25, 1.62, "input", ha="center", color=ink)

# Arrow
ax.add_patch(FancyArrowPatch((1.8, 2.5), (2.2, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Patches
patch_x0, patch_y0 = 2.55, 1.85
pw, gap = 0.18, 0.05
for i in range(4):
    for j in range(4):
        ax.add_patch(Rectangle(
            (patch_x0 + j*(pw+gap), patch_y0 + i*(pw+gap)),
            pw, pw, facecolor=soft_blue, edgecolor=blue, lw=0.6
        ))
ax.text(3.02, 1.42, "patches", ha="center", color=ink)

# Arrow
ax.add_patch(FancyArrowPatch((3.55, 2.5), (3.95, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Token embeddings
embed_x = 4.25
for i in range(4):
    ax.add_patch(Rectangle((embed_x, 1.78 + i*0.38), 0.52, 0.23,
                           facecolor="#bfdbfe", edgecolor=blue, lw=0.8))
ax.text(4.51, 1.42, "token\nembeddings", ha="center", color=ink)

# Arrow
ax.add_patch(FancyArrowPatch((4.88, 2.5), (5.28, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# MHSA blocks (simplified to 2)
attn_x = 5.55
for i, y in enumerate([2.9, 1.9]):
    ax.add_patch(Rectangle((attn_x, y), 0.9, 0.5,
                           facecolor=soft_blue, edgecolor=blue, lw=1.0))
    ax.text(attn_x + 0.45, y + 0.25, "MHSA", ha="center", va="center",
            color=ink, fontsize=9)

ax.text(6.0, 1.25, "attention\nblocks", ha="center", color=ink, fontsize=10)

# Global representation
ax.add_patch(FancyArrowPatch((6.48, 2.5), (6.95, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

ax.add_patch(Circle((7.22, 2.5), 0.16, facecolor=blue, edgecolor="none", alpha=0.9))
ax.text(7.22, 1.42, "global\nrepresentation", ha="center", color=ink)

# One curved arrow motif only
ax.add_patch(FancyArrowPatch((5.47, 1.95), (6.35, 3.15),
                             connectionstyle="arc3,rad=0.35",
                             arrowstyle="->", mutation_scale=9,
                             lw=1.0, color=blue, alpha=0.7))

ax.text(4.9, 4.15, "global sensitivity", color=blue, fontsize=11, ha="center")

# -------------------------
# Right panel: ResNet
# -------------------------
# Input
ax.add_patch(Rectangle((8.35, 2.0), 1.0, 1.0, facecolor="#cbd5e1", edgecolor=gray, lw=1.0))
ax.text(8.85, 1.62, "input", ha="center", color=ink)

# Arrow
ax.add_patch(FancyArrowPatch((9.45, 2.5), (9.82, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Conv stem
ax.add_patch(Rectangle((9.95, 2.05), 0.85, 0.9,
                       facecolor=soft_red, edgecolor=red, lw=1.0))
ax.text(10.375, 2.52, "conv", ha="center", va="center", color=ink, fontsize=10)
ax.text(10.375, 1.42, "local\nfeatures", ha="center", color=ink)

# Arrow
ax.add_patch(FancyArrowPatch((10.87, 2.5), (11.18, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))

# Residual blocks
res_xs = [11.35, 12.25, 13.15]
res_heights = [0.55, 0.72, 0.9]
for x0, h in zip(res_xs, res_heights):
    ax.add_patch(Rectangle((x0, 2.5 - h/2), 0.55, h,
                           facecolor=soft_red, edgecolor=red, lw=1.0))
    ax.text(x0 + 0.275, 2.5, "res", ha="center", va="center", color=ink, fontsize=9)

# small skip motifs
for x0 in res_xs:
    ax.add_patch(FancyArrowPatch((x0 + 0.02, 3.15), (x0 + 0.53, 3.15),
                                 connectionstyle="arc3,rad=0.4",
                                 arrowstyle="->", mutation_scale=7,
                                 lw=0.9, color=red, alpha=0.65))

# pooled representation
ax.add_patch(FancyArrowPatch((13.72, 2.5), (13.95, 2.5),
                             arrowstyle="->", mutation_scale=10,
                             lw=1.2, color=gray))
ax.add_patch(Circle((14.18, 2.5), 0.16, facecolor=red, edgecolor="none",
                    alpha=0.95, clip_on=False))
ax.text(14.02, 1.42, "pooled\nrepresentation", ha="center", color=ink)

ax.text(12.45, 4.1, "local / hierarchical sensitivity",
        color=red, fontsize=11, ha="center")

# -------------------------
# Shared takeaway
# -------------------------
ax.text(7.0, 0.55,
        "Different sensitivity pathways, same non-monotonic robustness law",
        ha="center", va="center", fontsize=11.5, color=ink)

plt.tight_layout(pad=1.0)
plt.savefig("fig_architecture_sensitivity_pathways_clean.pdf",
            format="pdf", bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 12,
    "axes.titlesize": 13,
    "axes.labelsize": 13,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "axes.linewidth": 0.9,
    "font.family": "serif",
})

# Color palette
ink = "#111827"
blue = "#1d4ed8"       # ViT
red = "#be123c"        # ResNet
gray = "#6b7280"
light = "#d1d5db"
band = "#dbeafe"

# Sensitivity axis
x = np.linspace(0.0, 1.0, 400)

# Two non-monotonic curves (stylized but plausible)
# ViT: peak slightly earlier
y_vit = -2.8 * (x - 0.46)**2 + 0.82
y_vit = np.clip(y_vit, 0.08, None)

# ResNet: peak slightly later and slightly flatter
y_res = -2.35 * (x - 0.54)**2 + 0.79
y_res = np.clip(y_res, 0.08, None)

# Shared optimal band (conceptual)
band_left, band_right = 0.38, 0.60

fig, ax = plt.subplots(figsize=(8.4, 4.9))

# Shaded band
ax.axvspan(band_left, band_right, color=band, alpha=0.75, zorder=0)

# Curves
ax.plot(x, y_vit, color=blue, lw=3.0, label="Tiny ViT")
ax.plot(x, y_res, color=red, lw=3.0, label="ResNet-18")

# Peaks
xv = x[np.argmax(y_vit)]
yv = np.max(y_vit)
xr = x[np.argmax(y_res)]
yr = np.max(y_res)

ax.scatter([xv], [yv], color=blue, s=70, zorder=5)
ax.scatter([xr], [yr], color=red, s=70, zorder=5)

# Peak labels
ax.text(xv - 0.05, yv + 0.03, "ViT peak", color=blue, fontsize=10)
ax.text(xr + 0.01, yr + 0.02, "ResNet peak", color=red, fontsize=10)

# Regime labels
ax.text(0.14, 0.18, "under-sensitive", color=gray, fontsize=11, ha="center")
ax.text(0.49, 0.14, "optimal sensitivity band", color=ink, fontsize=11, ha="center")
ax.text(0.82, 0.18, "over-sensitive", color=gray, fontsize=11, ha="center")

# Optional guide arrows
ax.annotate(
    "", xy=(0.28, 0.42), xytext=(0.16, 0.22),
    arrowprops=dict(arrowstyle="->", lw=1.0, color=gray)
)
ax.annotate(
    "", xy=(0.72, 0.40), xytext=(0.84, 0.22),
    arrowprops=dict(arrowstyle="->", lw=1.0, color=gray)
)

# Axes
ax.set_xlabel("Sensitivity")
ax.set_ylabel("Robustness under distribution shift")
ax.set_title("Shared sensitivity–robustness phase structure across architectures", color=ink, pad=10)

# Clean look
for s in ["top", "right"]:
    ax.spines[s].set_visible(False)
ax.spines["left"].set_color(light)
ax.spines["bottom"].set_color(light)

ax.set_xticks([])
ax.set_yticks([])
ax.legend(frameon=False, loc="upper left")

plt.tight_layout()
plt.savefig("fig_phase_diagram_sensitivity_robustness.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
vit_stable_logs.keys()
# Out:
# dict_keys(['step', 'train_loss', 'test_acc', 'sigma_mean', 'c10c_acc_mean', 'c10c_acc_std'])

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.dpi": 220,
    "savefig.dpi": 400,
    "font.size": 12,
    "axes.titlesize": 13,
    "axes.labelsize": 13,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "axes.linewidth": 0.9,
    "font.family": "serif",
})

def plot_multiseverity_sensitivity_curves(
    logs,
    model_name="Tiny ViT",
    severities=(1, 3, 5),
    outfile="appendix_multiseverity_curves.pdf"
):
    S = np.array(logs["sigma_mean"], dtype=float)
    A = np.array(logs["c10c_acc_per_severity"], dtype=float)  # shape [T, 5]

    fig, ax = plt.subplots(figsize=(7.2, 4.8))

    # Use default matplotlib colors; no manual colors
    for sev in severities:
        y = A[:, sev - 1]

        # sort by sensitivity for smooth plotting
        idx = np.argsort(S)
        x_sorted = S[idx]
        y_sorted = y[idx]

        ax.plot(x_sorted, y_sorted, marker="o", linewidth=2.2, label=f"severity {sev}")

    ax.set_xlabel("Sensitivity surrogate")
    ax.set_ylabel("CIFAR-10-C accuracy")
    ax.set_title(f"{model_name}: sensitivity–robustness across corruption severities")

    for spine in ["top", "right"]:
        ax.spines[spine].set_visible(False)

    ax.legend(frameon=False)
    plt.tight_layout()
    plt.savefig(outfile, format="pdf", bbox_inches="tight")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def quadratic_band(a, b, c, eta):
    """
    For R(S) = a S^2 + b S + c with a < 0,
    return S_star, R_star, (left, right) band for tolerance eta.
    """
    if a >= 0:
        raise ValueError("Quadratic must be concave (a < 0).")

    S_star = -b / (2 * a)
    R_star = a * S_star**2 + b * S_star + c
    target = (1 - eta) * R_star

    # Solve a S^2 + b S + c = target
    A = a
    B = b
    C = c - target
    disc = B**2 - 4 * A * C

    if disc < 0:
        return S_star, R_star, None

    sqrt_disc = np.sqrt(disc)
    s1 = (-B - sqrt_disc) / (2 * A)
    s2 = (-B + sqrt_disc) / (2 * A)
    left, right = min(s1, s2), max(s1, s2)

    return S_star, R_star, (left, right)


def plot_multieta_band_clean(
    S_points,
    R_points,
    a, b, c,
    model_name="Tiny ViT",
    etas=(0.01, 0.02, 0.05),
    outfile="multieta_band_clean.pdf"
):
    S_points = np.asarray(S_points, dtype=float)
    R_points = np.asarray(R_points, dtype=float)

    x_grid = np.linspace(S_points.min(), S_points.max(), 500)
    y_grid = a * x_grid**2 + b * x_grid + c

    plt.figure(figsize=(7.2, 4.8))

    # scatter + fit
    plt.scatter(S_points, R_points, s=45, alpha=0.85, label="Checkpoints")
    plt.plot(x_grid, y_grid, linewidth=2.6, label="Quadratic fit")

    # peak
    S_star = -b / (2 * a)
    R_star = a * S_star**2 + b * S_star + c
    plt.scatter([S_star], [R_star], s=80, zorder=5)
    plt.axvline(S_star, linestyle="--", linewidth=1.2)

    # sort eta so smallest band drawn last (on top)
    etas_sorted = sorted(etas, reverse=True)

    linestyles = ["-", "--", ":"]
    linewidths = [1.8, 1.5, 1.2]
    labels = ["1% Band", "2% Band", "5% Band"]

    for i, eta in enumerate(etas_sorted):
        _, _, band = quadratic_band(a, b, c, eta)
        if band is None:
            continue

        left, right = band

        # very light fill (same tone)
        plt.axvspan(left, right, alpha=0.08,color='orange')

        # distinct boundaries
        plt.axvline(left, linestyle=linestyles[i], linewidth=linewidths[i],label=labels[i],color='blue')
        plt.axvline(right, linestyle=linestyles[i], linewidth=linewidths[i],color='blue')

        # label near top
        #plt.text(
        #    (left + right) / 2,
        #    R_star - 0.01 - i * 0.01,
        #    rf"$\eta={int(eta*100)}\%$",
        #    ha="center",
        #    fontsize=11
        #)

    plt.xlabel("Sensitivity")
    plt.ylabel(r"Robustness $\mathcal{R}_5$")
    plt.title(f"{model_name}: optimal sensitivity band across $\\eta$")
    plt.legend(frameon=False)

    plt.tight_layout()
    plt.savefig(outfile, format="pdf", bbox_inches="tight")
    plt.show()

# %%
S_vit = np.array(vit_stable_logs["sigma_mean"] + vit_unstable_logs["sigma_mean"])
R_vit = np.array(vit_stable_logs["c10c_acc_mean"] + vit_unstable_logs["c10c_acc_mean"])

a_vit = -8.67560412977238
b_vit = 2.683503637299694
c_vit = 0.18257004953243244

plot_multieta_band_clean(
    S_vit, R_vit,
    a_vit, b_vit, c_vit,
    model_name="Tiny ViT",
    etas=(0.01, 0.02, 0.05),
    outfile="appendix_vit_multieta_band.pdf"
)

# %%
S_res = np.array(stable_logs["sigma_mean"] + unstable_logs["sigma_mean"])
R_res = np.array(stable_logs["c10c_acc_mean"] + unstable_logs["c10c_acc_mean"])

a_res = -8.185512372511893
b_res = 2.793768098208071
c_res = 0.23087130948319756

plot_multieta_band_clean(
    S_res, R_res,
    a_res, b_res, c_res,
    model_name="ResNet-18",
    etas=(0.01, 0.02, 0.05),
    outfile="appendix_resnet_multieta_band.pdf"
)

# %%
import matplotlib.pyplot as plt

def plot_eta_band_intervals(
    bands,
    s_star,
    model_name="Tiny ViT",
    outfile="eta_band_intervals.pdf"
):
    """
    bands: dict like
        {
            "1%": (left1, right1),
            "2%": (left2, right2),
            "5%": (left5, right5),
        }
    s_star: optimal sensitivity
    """

    labels = list(bands.keys())
    ys = list(range(len(labels), 0, -1))  # top to bottom

    fig, ax = plt.subplots(figsize=(7.0, 2.8))

    # vertical line for S*
    ax.axvline(s_star, linestyle="--", linewidth=1.4, color="black")
    ax.text(s_star, max(ys) + 0.35, r"$S^\*$", ha="center", va="bottom", fontsize=11)

    for y, label in zip(ys, labels):
        left, right = bands[label]
        ax.hlines(y, left, right, linewidth=6)
        ax.plot([left, right], [y, y], marker="|", markersize=16, linestyle="None")
        ax.text(right + 0.003, y, f"{label}: [{left:.3f}, {right:.3f}]",
                va="center", fontsize=10)

    ax.set_yticks(ys)
    ax.set_yticklabels([rf"$\eta={lab}$" for lab in labels])
    ax.set_xlabel("Sensitivity")
    ax.set_title(f"{model_name}: optimal sensitivity band across $\\eta$")

    # clean style
    for spine in ["top", "right", "left"]:
        ax.spines[spine].set_visible(False)
    ax.tick_params(axis="y", length=0)

    plt.tight_layout()
    plt.savefig(outfile, format="pdf", bbox_inches="tight")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_frontier(
    logs,
    model_name="Tiny ViT",
    outfile="frontier_plot.pdf"
):
    clean_acc = np.array(logs["test_acc"])
    robust_acc = np.array(logs["c10c_acc_mean"])
    sensitivity = np.array(logs["sigma_mean"])

    plt.figure(figsize=(6.8, 5.2))

    sc = plt.scatter(
        clean_acc,
        robust_acc,
        c=sensitivity,
        s=55,
        alpha=0.9
    )

    plt.xlabel("Clean Accuracy")
    plt.ylabel(r"Robustness $\mathcal{R}_5$")
    plt.title(f"{model_name}: robustness–accuracy frontier")

    # colorbar = sensitivity
    cbar = plt.colorbar(sc)
    cbar.set_label("Sensitivity")

    # clean style
    for spine in ["top", "right"]:
        plt.gca().spines[spine].set_visible(False)

    plt.tight_layout()
    plt.savefig(outfile, format="pdf", bbox_inches="tight")
    plt.show()

# %%
vit_stable_logs.keys()
# Out:
# dict_keys(['step', 'train_loss', 'test_acc', 'sigma_mean', 'c10c_acc_mean', 'c10c_acc_std'])

# %%
clean_acc = np.array(vit_stable_logs["test_acc"])
robust_acc = np.array(vit_stable_logs["c10c_acc_mean"])
sensitivity = np.array(vit_stable_logs["sigma_mean"])

# %%
S_star = 0.154  # your value

mask_opt = np.abs(sensitivity - S_star) < 0.01

plt.scatter(clean_acc[mask_opt], robust_acc[mask_opt],
            edgecolor="black", facecolor="none", s=90, linewidth=1.5,
            label="near $S^*$")
